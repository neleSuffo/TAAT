# %%
#read json file
import json
with open('/Users/nelesuffo/Promotion/projects/TAAT/categories/human_actions/100898.json', 'r') as file:
    data = json.load(file)

# %%
data['annotations'][0]
# Out:
# {'categoryId': 'human_actions',
#  'eventId': 'location',
#  'fields': {'Type of Location': 'Livingroom'},
#  'id': 'location_1745396774002',
#  'time': 0,
#  'type': 'start',
#  'videoName': '100898.MP4'}

# %%
# Read the JSON file
import json

with open('/Users/nelesuffo/Promotion/projects/TAAT/categories/human_actions/100898.json', 'r') as file:
    data = json.load(file)

# Extract all 'id' and 'startAnnotationId' values from the annotations
ids = {annotation['id'] for annotation in data['annotations'] if 'id' in annotation}
start_annotation_ids = {annotation['startAnnotationId'] for annotation in data['annotations'] if 'startAnnotationId' in annotation}

# Find IDs that are only in 'id' or only in 'startAnnotationId'
only_in_ids = ids - start_annotation_ids
only_in_start_annotation_ids = start_annotation_ids - ids

# Print the results
print("IDs only in 'id':", only_in_ids)
print("IDs only in 'startAnnotationId':", only_in_start_annotation_ids)
# Out:
# IDs only in 'id': set()
# IDs only in 'startAnnotationId': set()

# %% [markdown]
# ## Convert SuperAnnotate to TAAT format

# %%
import json
import time # For generating parts of unique IDs if needed
from pathlib import Path # Added for file operations

def get_taat_fields_for_event(event_id, sa_attributes):
    """
    Constructs the TAAT 'fields' object based on event_id and SuperAnnotate attributes.
    'sa_attributes' is expected to be a dictionary of attribute_name: attribute_value.
    """
    fields = {}
    # Ensure sa_attributes is a dictionary
    if not isinstance(sa_attributes, dict):
        sa_attributes = {}

    if event_id == "other_person_talking":
        fields["1st Person Age Group"] = sa_attributes.get("1st Person Age Group", "")
        fields["1st Person Gender"] = sa_attributes.get("1st Person Gender", "")
    elif event_id == "overheard_speech":
        pass # fields remains empty
    elif event_id == "location": # Specific handling for "location" eventId
        fields["Type of Location"] = sa_attributes.get("Type of Location", "")
    else:
        # Default "big setup" for other activities (like those derived from SA "Action")
        fields["Alone?"] = sa_attributes.get("Alone?", "")
        person_ordinals = {1: "1st", 2: "2nd", 3: "3rd", 4: "4th", 5: "5th", 6: "6th"}
        for i in range(1, 7):
            ordinal = person_ordinals[i]
            age_group_key = f"{ordinal} Person Age Group"
            gender_key = f"{ordinal} Person Gender"
            
            fields[age_group_key] = sa_attributes.get(age_group_key, "")
            fields[gender_key] = sa_attributes.get(gender_key, "")
    return fields

def convert_superannotate_to_taat_formats(superannotate_event_instances, video_name, category_id):
    """
    Converts a list of preprocessed SuperAnnotate event instances into detailed and concise TAAT formats.

    Args:
        superannotate_event_instances: A list of dictionaries. Each dictionary represents one
                                       SuperAnnotate event instance and should contain:
                                       - "taat_eventId": str (the derived TAAT eventId)
                                       - "startTimeSeconds": float
                                       - "endTimeSeconds": float
                                       - "attributes_for_taat": dict (attributes structured for get_taat_fields_for_event)
                                       - "instanceId_SA": str (optional, a unique ID from SuperAnnotate for the instance)
        video_name: str, The name of the video file (e.g., "711881.MP4").
        category_id: str, The category ID for these annotations (e.g., "human_actions").

    Returns:
        A tuple: (detailed_taat_output_dict, concise_taat_output_dict)
    """
    detailed_annotations_list = []
    concise_annotations_list = []
    instance_counter = 0 

    for sa_instance in superannotate_event_instances:
        taat_event_id = sa_instance.get("taat_eventId") # Use the derived TAAT eventId
        start_time = sa_instance.get("startTimeSeconds")
        end_time = sa_instance.get("endTimeSeconds")
        # Attributes specifically prepared for get_taat_fields_for_event
        attributes_for_taat = sa_instance.get("attributes_for_taat", {}) 

        if taat_event_id is None or start_time is None or end_time is None:
            print(f"Warning: Skipping preprocessed instance due to missing critical data: {sa_instance}")
            continue

        # Get TAAT fields using the derived taat_event_id and prepared attributes
        taat_fields = get_taat_fields_for_event(taat_event_id, attributes_for_taat)

        unique_suffix = f"{int(time.time() * 1000)}_{instance_counter}"
        # Use instanceId_SA if available, otherwise generate one with taat_event_id
        start_annotation_id = sa_instance.get("instanceId_SA", f"{taat_event_id}_{unique_suffix}")
        instance_counter += 1
        
        # 1. Detailed TAAT Format
        start_ann = {
            "id": start_annotation_id,
            "time": start_time,
            "categoryId": category_id,
            "eventId": taat_event_id,
            "fields": taat_fields,
            "type": "start",
            "videoName": video_name 
        }
        detailed_annotations_list.append(start_ann)

        end_ann = {
            "time": end_time,
            "categoryId": category_id,
            "eventId": taat_event_id,
            "type": "end",
            "startAnnotationId": start_annotation_id,
            "fields": taat_fields, 
            "videoName": video_name 
        }
        detailed_annotations_list.append(end_ann)

        # 2. Concise TAAT Format
        duration = end_time - start_time
        concise_ann = {
            "time": start_time, 
            "categoryId": category_id,
            "eventId": taat_event_id,
            "fields": taat_fields,
            "type": "complete",
            "videoName": video_name, 
            "startTime": start_time,
            "endTime": end_time,
            "duration": duration
        }
        concise_annotations_list.append(concise_ann)

    detailed_taat_output = {
        "video_name": video_name,
        "category_id": category_id,
        "annotations": detailed_annotations_list,
        "activeAnnotations": {} 
    }

    concise_taat_output = {
        "video_name": video_name,
        "category_id": category_id,
        "annotations": concise_annotations_list,
        "activeAnnotations": {} 
    }

    return detailed_taat_output, concise_taat_output

def preprocess_superannotate_data(sa_json_data_filepath, category_id_for_taat, default_video_name="unknown.mp4"):
    """
    Loads SuperAnnotate JSON from a file and preprocesses it into the format
    expected by 'convert_superannotate_to_taat_formats'.
    """
    try:
        with open(sa_json_data_filepath, 'r') as f:
            sa_data = json.load(f)
    except Exception as e:
        print(f"Error loading SuperAnnotate JSON file '{sa_json_data_filepath}': {e}")
        return None, [] # Return None for video_name if file can't be loaded

    preprocessed_instances = []
    
    video_name = sa_data.get("metadata", {}).get("name", default_video_name)
    if video_name == default_video_name:
        print(f"Warning: Using default video name '{default_video_name}' for file '{sa_json_data_filepath}'")

    sa_instances_list = sa_data.get("instances", []) 

    for instance in sa_instances_list:
        meta = instance.get("meta", {})
        instance_type = meta.get("type")

        if instance_type != "event": 
            continue

        sa_class_name = meta.get("className") 
        instance_id_sa = meta.get("id")
        
        # Parameters list, default to empty list if not found
        parameters = instance.get("parameters", [])
        if not parameters: # Ensure parameters list is not empty
            print(f"Skipping instance (ID: {instance_id_sa}): 'parameters' list is missing or empty.")
            continue
        
        # Event times are in microseconds, convert to seconds
        # Default to None if keys are missing
        start_time_microseconds = parameters[0].get("start")
        end_time_microseconds = parameters[0].get("end")

        if start_time_microseconds is None or end_time_microseconds is None:
            print(f"Skipping instance (ID: {instance_id_sa}): missing start or end time in parameters.")
            continue
            
        start_time_s = float(start_time_microseconds) / 1_000_000.0
        end_time_s = float(end_time_microseconds) / 1_000_000.0
        
        # Extract attributes from the first timestamp object
        # Uses .get() with defaults to avoid errors if structure is slightly different
        timestamps = parameters[0].get("timestamps", [])
        if not timestamps: # Ensure timestamps list is not empty
            print(f"Skipping instance (ID: {instance_id_sa}): 'timestamps' list is missing or empty in parameters.")
            continue

        sa_attributes_list = timestamps[0].get("attributes", [])
        attributes_dict = {} # Stores {groupName: name}
        for attr in sa_attributes_list:
            group_name = attr.get("groupName")
            attr_name_val = attr.get("name") # This is the actual value of the attribute
            if group_name and attr_name_val is not None:
                attributes_dict[group_name] = attr_name_val
        
        # Determine TAAT eventId and the attributes to pass to get_taat_fields_for_event
        taat_event_id = None
        attributes_for_taat_fields = {}

        if sa_class_name == "Location":
            taat_event_id = "location"
            # For "location", get_taat_fields_for_event expects {"Type of Location": value}
            attributes_for_taat_fields["Type of Location"] = attributes_dict.get("Type of Location")
        elif sa_class_name == "Action":
            type_of_action = attributes_dict.get("Type of Action")
            if type_of_action:
                taat_event_id = type_of_action.lower().replace(" ", "_")
                # For "Action" types, pass all extracted SA attributes.
                # get_taat_fields_for_event will pick what it needs based on the derived taat_event_id.
                attributes_for_taat_fields = attributes_dict.copy()
            else:
                print(f"Skipping 'Action' instance (ID: {instance_id_sa}): 'Type of Action' attribute missing.")
                continue
        else:
            # Fallback for other SuperAnnotate classNames if any
            if sa_class_name:
                taat_event_id = sa_class_name.lower().replace(" ", "_")
                attributes_for_taat_fields = attributes_dict.copy()
            else:
                print(f"Skipping instance (ID: {instance_id_sa}): 'className' is missing in meta.")
                continue
        
        if not taat_event_id: # Should be caught by earlier continues, but as a safeguard
            print(f"Skipping instance (ID: {instance_id_sa}): Could not determine TAAT eventId.")
            continue

        preprocessed_instances.append({
            "taat_eventId": taat_event_id,
            "startTimeSeconds": start_time_s,
            "endTimeSeconds": end_time_s,
            "attributes_for_taat": attributes_for_taat_fields,
            "instanceId_SA": instance_id_sa 
        })
        
    return video_name, preprocessed_instances


def batch_process_superannotate_files(input_directory, output_directory_detailed, output_directory_concise, category_id_for_taat):
    input_dir = Path(input_directory)
    output_dir_detailed = Path(output_directory_detailed)
    output_dir_concise = Path(output_directory_concise)

    output_dir_detailed.mkdir(parents=True, exist_ok=True)
    output_dir_concise.mkdir(parents=True, exist_ok=True)

    processed_count = 0
    error_count = 0

    for file_path in input_dir.glob('*.json'):
        print(f"\nProcessing file: {file_path.name}")
        
        # category_id_for_taat can be dynamic here if needed, e.g., from folder name
        video_name, preprocessed_instances = preprocess_superannotate_data(file_path, category_id_for_taat)

        if video_name is None or not preprocessed_instances:
            print(f"Failed to preprocess or no instances found in {file_path.name}. Skipping.")
            error_count +=1
            continue
        
        if not preprocessed_instances: # Double check after preprocessing call
            print(f"No processable instances found in {file_path.name} after preprocessing. Skipping.")
            continue

        detailed_output, concise_output = convert_superannotate_to_taat_formats(
            preprocessed_instances,
            video_name, # Use video_name extracted from SA file
            category_id_for_taat
        )

        # Prepare output filenames
        base_filename = video_name.replace('.MP4', '') # Remove .MP4 if present
        if not base_filename: # Handle cases where video_name might be just ".MP4" or empty
            base_filename = file_path.stem # Fallback to original file stem

        output_path_detailed = output_dir_detailed / f"{base_filename}.json"
        output_path_concise = output_dir_concise / f"{base_filename}.json" # Your desired output format

        try:
            with output_path_detailed.open('w') as outfile:
                json.dump(detailed_output, outfile, indent=4)
            print(f"Saved detailed TAAT to: {output_path_detailed}")

            with output_path_concise.open('w') as outfile:
                json.dump(concise_output, outfile, indent=4)
            print(f"Saved concise TAAT to: {output_path_concise}")
            processed_count += 1
        except Exception as e:
            print(f"Error saving output for {file_path.name}: {e}")
            error_count += 1
            
    print(f"\nBatch processing complete. Processed files: {processed_count}, Errors: {error_count}")

# %%
SA_INPUT_DIR = '/Users/nelesuffo/Promotion/ProcessedData/annotations_superannotate'
TAAT_OUTPUT_DIR_DETAILED = '/Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format'
TAAT_OUTPUT_DIR_CONCISE = '/Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final' # For your target format
TAAT_CATEGORY_ID = "human_actions" # Assuming this is constant for all files in this batch

batch_process_superannotate_files(
    SA_INPUT_DIR, 
    TAAT_OUTPUT_DIR_DETAILED, 
    TAAT_OUTPUT_DIR_CONCISE, 
    TAAT_CATEGORY_ID
)

print("Processing finished. Check the output directories.")
# Out:
# Processing file: 410731.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/410731.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/410731.json
#
# Processing file: 488644.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/488644.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/488644.json
#
# Processing file: 183537.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/183537.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/183537.json
#
# Processing file: 487661.MP4.json
# Skipping 'Action' instance (ID: Mjg3OTAzMDAuMTkzNzQxNzM=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/487661.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/487661.json
#
# Processing file: 331649.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/331649.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/331649.json
#
# Processing file: 259814.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/259814.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/259814.json
#
# Processing file: 244555.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/244555.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/244555.json
#
# Processing file: 442279.MP4.json
# Skipping 'Action' instance (ID: NTc2ODM2Ljc0NTkyNjAxMjM=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/442279.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/442279.json
#
# Processing file: 370090.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/370090.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/370090.json
#
# Processing file: 208080.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/208080.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/208080.json
#
# Processing file: 339217.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/339217.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/339217.json
#
# Processing file: 520498.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/520498.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/520498.json
#
# Processing file: 403769.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/403769.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/403769.json
#
# Processing file: 206914.MP4.json
# Skipping 'Action' instance (ID: ODAyMjk5MS43NjQyODk0OTI=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/206914.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/206914.json
#
# Processing file: 503253.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/503253.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/503253.json
#
# Processing file: 940000.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/940000.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/940000.json
#
# Processing file: 532883.MP4.json
# Skipping 'Action' instance (ID: NTMxNzM1NjEuNTQ2MDU5MjQ=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/532883.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/532883.json
#
# Processing file: 268483.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/268483.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/268483.json
#
# Processing file: 448237.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/448237.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/448237.json
#
# Processing file: 520977.MP4.json
# Skipping 'Action' instance (ID: NDQxNjA0NC4xNzQzNzgwMjY=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/520977.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/520977.json
#
# Processing file: 542919.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/542919.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/542919.json
#
# Processing file: 463097.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/463097.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/463097.json
#
# Processing file: 289287.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/289287.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/289287.json
#
# Processing file: 336244.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/336244.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/336244.json
#
# Processing file: 504907.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/504907.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/504907.json
#
# Processing file: 533763.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/533763.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/533763.json
#
# Processing file: 172296.MP4.json
# Skipping 'Action' instance (ID: MTIyMTU0MzEuMzQ1MjczMQ==): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/172296.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/172296.json
#
# Processing file: 310644.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/310644.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/310644.json
#
# Processing file: 306565.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/306565.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/306565.json
#
# Processing file: 418396.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/418396.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/418396.json
#
# Processing file: 319731.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/319731.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/319731.json
#
# Processing file: 365653.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/365653.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/365653.json
#
# Processing file: 309992.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/309992.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/309992.json
#
# Processing file: 394148.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/394148.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/394148.json
#
# Processing file: 684742.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/684742.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/684742.json
#
# Processing file: 186666.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/186666.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/186666.json
#
# Processing file: 207949.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/207949.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/207949.json
#
# Processing file: 273077.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/273077.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/273077.json
#
# Processing file: 386054.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/386054.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/386054.json
#
# Processing file: 360698.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/360698.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/360698.json
#
# Processing file: 310699.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/310699.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/310699.json
#
# Processing file: 284099.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/284099.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/284099.json
#
# Processing file: 100898.MP4.json
# Skipping 'Action' instance (ID: MTE2ODMxOS4zNjczMzMwMDkx): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/100898.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/100898.json
#
# Processing file: 319263.MP4.json
# Skipping 'Action' instance (ID: MjM5OTk4NzEuNDU2NzQ2MzY2): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/319263.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/319263.json
#
# Processing file: 341934.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/341934.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/341934.json
#
# Processing file: 543575.MP4.json
# Skipping 'Action' instance (ID: ODg5NjE5NjcuMDQ4OTY5Ng==): 'Type of Action' attribute missing.
# Skipping 'Action' instance (ID: MjY2ODAxNy43NTc4NzI4MTI=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/543575.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/543575.json
#
# Processing file: 800386.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/800386.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/800386.json
#
# Processing file: 300654.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/300654.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/300654.json
#
# Processing file: 776563.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/776563.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/776563.json
#
# Processing file: 483937.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/483937.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/483937.json
#
# Processing file: 243869.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/243869.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/243869.json
#
# Processing file: 390059.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/390059.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/390059.json
#
# Processing file: 607715.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/607715.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/607715.json
#
# Processing file: 121497.MP4.json
# Skipping 'Action' instance (ID: MjE2NjM4MTEuMjgwODI5ODU=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/121497.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/121497.json
#
# Processing file: 252829.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/252829.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/252829.json
#
# Processing file: 445266.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/445266.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/445266.json
#
# Processing file: 519475.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/519475.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/519475.json
#
# Processing file: 212983.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/212983.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/212983.json
#
# Processing file: 172864.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/172864.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/172864.json
#
# Processing file: 364368.MP4.json
# Skipping 'Action' instance (ID: MTYxMTgxMTAuNDU3NDM2MjE3): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/364368.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/364368.json
#
# Processing file: 497568.MP4.json
# Skipping 'Action' instance (ID: MjE4MzM4My42NjcxNTU1Njg=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/497568.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/497568.json
#
# Processing file: 153069.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/153069.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/153069.json
#
# Processing file: 540737.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/540737.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/540737.json
#
# Processing file: 425618.MP4.json
# Skipping 'Action' instance (ID: MjY4NzYyLjA0NTA1MjI2NzE=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/425618.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/425618.json
#
# Processing file: 217622.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/217622.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/217622.json
#
# Processing file: 290185.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/290185.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/290185.json
#
# Processing file: 888824.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/888824.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/888824.json
#
# Processing file: 126181.MP4.json
# Skipping 'Action' instance (ID: MTQ5MTc0NDcuNzkwMjQzNjMx): 'Type of Action' attribute missing.
# Skipping 'Action' instance (ID: NDE1ODA1MC4xOTU0NjQxMjU=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/126181.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/126181.json
#
# Processing file: 139665.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/139665.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/139665.json
#
# Processing file: 108844.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/108844.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/108844.json
#
# Processing file: 351105.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/351105.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/351105.json
#
# Processing file: 204839.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/204839.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/204839.json
#
# Processing file: 225457.MP4.json
# Skipping 'Action' instance (ID: MTAzNzM3ODMuNzA3MjM1MDQ0): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/225457.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/225457.json
#
# Processing file: 209812.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/209812.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/209812.json
#
# Processing file: 387058.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/387058.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/387058.json
#
# Processing file: 207115.MP4.json
# Skipping 'Action' instance (ID: NTM5ODc5MjkuMDMyMjQ1NjM=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/207115.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/207115.json
#
# Processing file: 516537.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/516537.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/516537.json
#
# Processing file: 283598.MP4.json
# Skipping 'Action' instance (ID: MTAzMzExNTMuNzgxODY2MzIz): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/283598.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/283598.json
#
# Processing file: 405664.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/405664.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/405664.json
#
# Processing file: 537865.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/537865.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/537865.json
#
# Processing file: 282498.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/282498.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/282498.json
#
# Processing file: 350145.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/350145.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/350145.json
#
# Processing file: 252685.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/252685.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/252685.json
#
# Processing file: 346638.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/346638.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/346638.json
#
# Processing file: 190053.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/190053.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/190053.json
#
# Processing file: 424217.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/424217.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/424217.json
#
# Processing file: 779724.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/779724.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/779724.json
#
# Processing file: 365908.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/365908.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/365908.json
#
# Processing file: 445489.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/445489.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/445489.json
#
# Processing file: 214201.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/214201.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/214201.json
#
# Processing file: 757253.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/757253.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/757253.json
#
# Processing file: 182442.MP4.json
# Skipping 'Action' instance (ID: MjU2NzMxMzQuNTAyMTI0MzY=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/182442.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/182442.json
#
# Processing file: 401590.MP4.json
# Skipping 'Action' instance (ID: NjYxMDUuNDU2MDAwODQ3MTI=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/401590.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/401590.json
#
# Processing file: 468002.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/468002.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/468002.json
#
# Processing file: 195594.MP4.json
# Skipping 'Action' instance (ID: MTAxNzIyMzIwLjc0NzY1MTA2): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/195594.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/195594.json
#
# Processing file: 184452.MP4.json
# Skipping 'Action' instance (ID: ODM1MDY5My4wMjQ4MTE2Nzk1): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/184452.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/184452.json
#
# Processing file: 536025.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/536025.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/536025.json
#
# Processing file: 136375.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/136375.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/136375.json
#
# Processing file: 378856.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/378856.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/378856.json
#
# Processing file: 891069.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/891069.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/891069.json
#
# Processing file: 297002.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/297002.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/297002.json
#
# Processing file: 353625.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/353625.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/353625.json
#
# Processing file: 688731.MP4.json
# Skipping 'Action' instance (ID: OTc3NzU3NC4zODQ1MzMyODY=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/688731.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/688731.json
#
# Processing file: 457472.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/457472.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/457472.json
#
# Processing file: 447674.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/447674.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/447674.json
#
# Processing file: 417338.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/417338.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/417338.json
#
# Processing file: 139229.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/139229.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/139229.json
#
# Processing file: 275212.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/275212.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/275212.json
#
# Processing file: 124215.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/124215.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/124215.json
#
# Processing file: 117071.MP4.json
# Skipping 'Action' instance (ID: MjAzNzc3NzIuMzQ4NDA4ODkz): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/117071.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/117071.json
#
# Processing file: 556915.MP4.json
# Skipping 'Action' instance (ID: NTcwOTQwNy45MTE2NDgyMjc=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/556915.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/556915.json
#
# Processing file: 414660.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/414660.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/414660.json
#
# Processing file: 128872.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/128872.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/128872.json
#
# Processing file: 152333.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/152333.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/152333.json
#
# Processing file: 472508.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/472508.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/472508.json
#
# Processing file: 547935.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/547935.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/547935.json
#
# Processing file: 171099.MP4.json
# Skipping 'Action' instance (ID: NjU5MjIyNC4xNzQ4MjM4OA==): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/171099.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/171099.json
#
# Processing file: 267118.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/267118.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/267118.json
#
# Processing file: 414831.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/414831.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/414831.json
#
# Processing file: 208409.MP4.json
# Skipping 'Action' instance (ID: NDc4NjY1OS4zNjQ1MTE1ODg=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/208409.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/208409.json
#
# Processing file: 512533.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/512533.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/512533.json
#
# Processing file: 305277.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/305277.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/305277.json
#
# Processing file: 326740.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/326740.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/326740.json
#
# Processing file: 185049.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/185049.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/185049.json
#
# Processing file: 432722.MP4.json
# Skipping 'Action' instance (ID: Mjg0MjkwNC45NzIwMjIxNDgz): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/432722.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/432722.json
#
# Processing file: 227279.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/227279.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/227279.json
#
# Processing file: 533034.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/533034.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/533034.json
#
# Processing file: 138513.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/138513.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/138513.json
#
# Processing file: 418220.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/418220.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/418220.json
#
# Processing file: 384179.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/384179.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/384179.json
#
# Processing file: 287342.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/287342.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/287342.json
#
# Processing file: 189224.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/189224.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/189224.json
#
# Processing file: 147984.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/147984.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/147984.json
#
# Processing file: 205296.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/205296.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/205296.json
#
# Processing file: 541444.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/541444.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/541444.json
#
# Processing file: 440485.MP4.json
# Skipping 'Action' instance (ID: MjQxNjE0NjEuMzkyNzI0NDk=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/440485.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/440485.json
#
# Processing file: 817697.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/817697.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/817697.json
#
# Processing file: 475930.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/475930.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/475930.json
#
# Processing file: 393278.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/393278.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/393278.json
#
# Processing file: 261409.MP4.json
# Skipping 'Action' instance (ID: NDgxMzU0NjEuODQ2MTk0NA==): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/261409.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/261409.json
#
# Processing file: 504190.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/504190.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/504190.json
#
# Processing file: 883783.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/883783.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/883783.json
#
# Processing file: 264487.MP4.json
# Skipping 'Action' instance (ID: MTYwOTI0MDcuNjYwMTc0MDE2): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/264487.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/264487.json
#
# Processing file: 528813.MP4.json
# Skipping 'Action' instance (ID: MTI0MzA5MjcuNTAwNTE0OTQ1): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/528813.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/528813.json
#
# Processing file: 486149.MP4.json
# Skipping 'Action' instance (ID: MTkxNjU5MzMuNDQ1NjY4MDY=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/486149.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/486149.json
#
# Processing file: 467868.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/467868.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/467868.json
#
# Processing file: 160606.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/160606.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/160606.json
#
# Processing file: 367575.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/367575.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/367575.json
#
# Processing file: 524655.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/524655.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/524655.json
#
# Processing file: 805896.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/805896.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/805896.json
#
# Processing file: 114534.MP4.json
# Skipping 'Action' instance (ID: NjA2OTAxNC4zOTI4ODcxOTY1): 'Type of Action' attribute missing.
# Skipping 'Action' instance (ID: MzY3NjEzMDcuNTE5NDUxODY=): 'Type of Action' attribute missing.
# Skipping 'Action' instance (ID: MzcwNDU4OTEuNDc3Njk4NDQ1): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/114534.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/114534.json
#
# Processing file: 225742.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/225742.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/225742.json
#
# Processing file: 106910.MP4.json
# Skipping 'Action' instance (ID: MzgxMjQ1MS45ODQ3MDQwOTk=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/106910.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/106910.json
#
# Processing file: 390182.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/390182.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/390182.json
#
# Processing file: 476848.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/476848.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/476848.json
#
# Processing file: 210803.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/210803.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/210803.json
#
# Processing file: 385152.MP4.json
# Skipping 'Action' instance (ID: MzY4NzIyODIuNTEzNTQ1NzY=): 'Type of Action' attribute missing.
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/385152.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/385152.json
#
# Processing file: 371111.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/371111.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/371111.json
#
# Processing file: 119281.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/119281.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/119281.json
#
# Processing file: 493644.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/493644.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/493644.json
#
# Processing file: 672793.MP4.json
# Saved detailed TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/platform_format/672793.json
# Saved concise TAAT to: /Users/nelesuffo/Promotion/ProcessedData/annotations_keeper/final/672793.json
#
# Batch processing complete. Processed files: 161, Errors: 0
# Processing finished. Check the output directories.
